# %% [markdown]
# # Data Workflow Lab 1
#
# Clean and summarize Project 3 data.
#
# ### Learning Objectives
#
# * Practice text cleaning techniques
# * Practice datatype conversion
# * Practice filling in missing values with either 0 or the average in the column
# * Practice categorical data techniques
# * Transform data into usable quantities

# %%
% matplotlib inline
import datetime
import numpy as np
import pandas as pd

# %%
# Load the data
df = pd.read_csv("/Users/davidswan/Downloads/Iowa_Liquor_Sales_sample_10pct.csv")
print df.columns
df.head()
# Out:
# Index([u'Date', u'Store Number', u'City', u'Zip Code', u'County Number',
#        u'County', u'Category', u'Category Name', u'Vendor Number',
#        u'Item Number', u'Item Description', u'Bottle Volume (ml)',
#        u'State Bottle Cost', u'State Bottle Retail', u'Bottles Sold',
#        u'Sale (Dollars)', u'Volume Sold (Liters)', u'Volume Sold (Gallons)'],
#       dtype='object')
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %% [markdown]
# ## Clean the data
#
# Let's practice our data cleaning skills on the Project 3 dataset. If you don't remember how to do any of these tasks, look back at your work from the previous weeks or search the internet. There are many blog articles and Stack Overflow posts that cover these topics.
#
# You'll want to complete at least the following tasks:
# * Remove redundant columns
# * Remove "$" prices from characters and convert values to floats.
# * Convert dates to pandas datetime objects
# * Convert category floats to integers
# * Drop or fill in bad values

# %%
# Remove redundant columns
df.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  03/31/2016          5029    DAVENPORT    52806           82.0       Scott
# 1  03/31/2016          5029    DAVENPORT    52806           82.0       Scott
# 2  03/31/2016          4959  CEDAR FALLS    50613            7.0  Black Hawk
# 3  03/31/2016          2190   DES MOINES    50314           77.0        Polk
# 4  03/31/2016          5240  WEST BRANCH    52358            NaN         NaN
#
#     Category       Category Name  Vendor Number  Item Number  \
# 0  1022100.0             TEQUILA            370        87152
# 1  1022100.0             TEQUILA            395        89197
# 2  1071100.0  AMERICAN COCKTAILS            380        63959
# 3  1031200.0      VODKA FLAVORED            205        40597
# 4  1081200.0      CREAM LIQUEURS            305        73055
#
#                         Item Description  Bottle Volume (ml)  \
# 0                           Avion Silver                 375
# 1  Jose Cuervo Especial Reposado Tequila                1000
# 2         Uv Blue Raspberry Lemonade Pet                1750
# 3                New Amsterdam Red Berry                 200
# 4                               Rumchata                 750
#
#    State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 0               9.99              $14.99            12        $179.88
# 1              12.50              $18.75             2         $37.50
# 2               5.97               $8.96             6         $53.76
# 3               2.24               $3.36            48        $161.28
# 4              12.50              $18.75             6        $112.50
#
#    Volume Sold (Liters)  Volume Sold (Gallons)
# 0                   4.5                   1.19
# 1                   2.0                   0.53
# 2                  10.5                   2.77
# 3                   9.6                   2.54
# 4                   4.5                   1.19

# %%
# Remove $ from certain columns
# bottleCost = df[['State Bottle Cost']]
df['State Bottle Cost'] = df['State Bottle Cost'].str.replace(r'[$,]', '').astype('float')

df['State Bottle Retail'] = df['State Bottle Retail'].str.replace(r'[$,]', '').astype('float')

# %%
df['Sale (Dollars)'] = df['Sale (Dollars)'].str.replace(r'[$,]', '').astype('float')

# %%
df
# Out:
#               Date  Store Number             City Zip Code  County Number  \
# 0       11/04/2015          3717           SUMNER    50674            9.0
# 1       03/02/2016          2614        DAVENPORT    52807           82.0
# 2       02/11/2016          2106      CEDAR FALLS    50613            7.0
# 3       02/03/2016          2501             AMES    50010           85.0
# 270951  11/04/2015          5151        IDA GROVE    51445           47.0
# 270952  10/20/2015          5152         WATERLOO    50702            7.0
# 270953  11/20/2015          3562  WEST BURLINGTON    52655           29.0
# 270954  01/27/2015          4446        URBANDALE    50322           77.0
#
#                County   Category                       Category Name  \
# 0              Bremer  1051100.0                    APRICOT BRANDIES
# 1               Scott  1011100.0                    BLENDED WHISKIES
# 2          Black Hawk  1011200.0           STRAIGHT BOURBON WHISKIES
# 3               Story  1071100.0                  AMERICAN COCKTAILS
# 4              Wright  1031080.0                      VODKA 80 PROOF
# 5                Linn  1041100.0                   AMERICAN DRY GINS
# 6             Wapello  1051010.0             AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                   CANADIAN WHISKIES
# 8                Polk  1032080.0                      IMPORTED VODKA
# 9              Benton  1081315.0                   CINNAMON SCHNAPPS
# 10               Polk  1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                  AMERICAN COCKTAILS
# 12              Scott  1012100.0                   CANADIAN WHISKIES
# 13                Lee  1081300.0                 PEPPERMINT SCHNAPPS
# 14            Johnson  1031200.0                      VODKA FLAVORED
# 15             Bremer  1051100.0                    APRICOT BRANDIES
# 16         Black Hawk  1031100.0                     100 PROOF VODKA
# 17            Mahaska  1031200.0                      VODKA FLAVORED
# 18             Jasper  1081700.0         DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                   CANADIAN WHISKIES
# 20               Linn  1031200.0                      VODKA FLAVORED
# 21               Tama  1012100.0                   CANADIAN WHISKIES
# 22              Sioux  1011100.0                    BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                             TEQUILA
# 24               Linn  1031080.0                      VODKA 80 PROOF
# 25          Dickinson  1011300.0                  TENNESSEE WHISKIES
# 26            Johnson  1012100.0                   CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                    BLENDED WHISKIES
# 28               Polk  1031080.0                      VODKA 80 PROOF
# 29            Johnson  1081600.0                     WHISKEY LIQUEUR
# ...               ...        ...                                 ...
# 270925     Black Hawk  1081200.0                      CREAM LIQUEURS
# 270926           Polk  1022100.0                             TEQUILA
# 270927           Polk  1031200.0                      VODKA FLAVORED
# 270928        Johnson  1031080.0                      VODKA 80 PROOF
# 270929      Muscatine  1031080.0                      VODKA 80 PROOF
# 270930           Linn  1031080.0                      VODKA 80 PROOF
# 270931       Hamilton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270932         Jasper  1011300.0                  TENNESSEE WHISKIES
# 270933          Story  1062310.0                          SPICED RUM
# 270934       Woodbury  1051110.0                 BLACKBERRY BRANDIES
# 270935           Polk  1011300.0                  TENNESSEE WHISKIES
# 270936           Linn  1022100.0                             TEQUILA
# 270937          Union  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270938           Linn  1031080.0                      VODKA 80 PROOF
# 270939           Linn  1031200.0                      VODKA FLAVORED
# 270940      Appanoose  1012200.0                     SCOTCH WHISKIES
# 270941           Linn  1031080.0                      VODKA 80 PROOF
# 270942        Johnson  1011100.0                    BLENDED WHISKIES
# 270943          Story  1011200.0           STRAIGHT BOURBON WHISKIES
# 270944           Polk  1081240.0               GREEN CREME DE MENTHE
# 270945           Polk  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
#
bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 0                      750               4.50                 6.75
# 1                      750              13.75                20.63
# 2                     1000              12.59                18.89
# 3                     1750               9.50                14.25
# 4                     1750               7.20                10.80
# 5                     1750              13.32                19.98
# 6                      750               6.66                 9.99
# 7                     1750              15.75                23.63
# 8                      750              11.49                17.24
# 9                     1000               7.62                11.43
# 10                     750              26.24                39.36
# 11                    1750               6.00                 9.25
# 12                    1750               8.92                13.38
# 13                     750              10.00                15.00
# 14                    1000               7.50                11.25
# 15                     750               4.50                 6.75
# 16                     200               1.13                 1.70
# 17                     750               6.50                 9.75
# 18                    1000               4.92                 7.38
# 19                    1750               9.97                14.96
# 20                     750              14.25                21.38
# 21                     750               5.23                 7.85
# 22                     750               7.00                10.50
# 23                     750              10.49                15.74
# 24                     750               3.37                 5.06
# 25                    1000              17.90                26.85
# 26                     300               7.35                11.03
# 27                     750               3.50                 5.25
# 28                    1750              10.99                16.49
# 29                     500               4.90                 7.35
# ...                    ...                ...                  ...
# 270925                 750               6.00                 9.00
# 270926                 750              31.00                46.50
# 270927                1000               9.25                13.88
# 270928                 375               1.80                 2.70
# 270929                 750               3.57                 5.36
# 270930                 375               1.93                 2.90
# 270931                 750               5.25                 7.88
# 270932                1750              29.67                44.51
# 270933                 750               9.00                13.50
# 270934                1750              10.00                15.00
# 270935                 750              15.07                22.61
# 270936                 750              10.49                15.74
# 270937                 750              18.56                27.84
# 270938                 375               4.75                 7.13
# 270939                 500               4.89                 7.34
# 270940                 750              12.03                18.05
# 270941                1750               6.68                10.27
# 270942                 750               5.51                 8.27
# 270943                 500               6.83                10.25
# 270944                 750               4.75                 7.13
# 270945                 100               0.89                 1.34
# 270946                 750               9.65                14.48
# 270947                 375               5.00                 7.50
# 270948                 750               8.50                12.75
# 270949                1000               4.13                 6.20
# 270950                 300              20.30                30.45
# 270951                 750               7.47                11.21
# 270952                 750              15.07                22.61
# 270953                1750              26.05                39.08
# 270954                 200               2.75                 4.13
#
#         Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 12           81.00                  9.00
# 1                  2           41.26                  1.50
# 2                 24          453.36                 24.00
# 3                  6           85.50                 10.50
# 4                 12          129.60                 21.00
# 5                  6          119.88                 10.50
# 6                  3           29.97                  2.25
# 7                  2           47.26                  3.50
# 8                  4           68.96                  3.00
# 9                  2           22.86                  2.00
# 10                 6          236.16                  4.50
# 11                 6           55.50                 10.50
# 12                 1           13.38                  1.75
# 13                12          180.00                  9.00
# 14                12          135.00                 12.00
# 15                 4           27.00                  3.00
# 16                48           81.60                  9.60
# 17                12          117.00                  9.00
# 18                24          177.12                 24.00
# 19                 6           89.76                 10.50
# 20                 2           42.76                  1.50
# 21                12           94.20                  9.00
# 22                12          126.00                  9.00
# 23                12          188.88                  9.00
# 24                12           60.72                  9.00
# 25                24          644.40                 24.00
# 26                 1           11.03                  0.30
# 27                 3           15.75                  2.25
# 28                 6           98.94                 10.50
# 29                 1            7.35                  0.50
# ...              ...             ...                   ...
# 270925             4           36.00                  3.00
# 270926             6          279.00                  4.50
# 270927            12          166.56                 12.00
# 270928            48          129.60                 18.00
# 270929             4           21.44                  3.00
# 270930            12           34.80                  4.50
# 270931            12           94.56                  9.00
# 270932             2           89.02                  3.50
# 270933             3           40.50                  2.25
# 270934             2           30.00                  3.50
# 270935             3           67.83                  2.25
# 270936            12          188.88                  9.00
# 270937             1           27.84                  0.75
# 270938             3           21.39                  1.12
# 270939             6           44.04                  3.00
# 270940             4           72.20                  3.00
# 270941             6           61.62                 10.50
# 270942            12           99.24                  9.00
# 270943             1           10.25                  0.50
# 270944             2           14.26                  1.50
# 270945            48           64.32                  4.80
# 270946             4           57.92                  3.00
# 270947             6           45.00                  2.25
# 270948             3           38.25                  2.25
# 270949             3           18.60                  3.00
# 270950             4          121.80                  1.20
# 270951             3           33.63                  2.25
# 270952             6          135.66                  4.50
# 270953             6          234.48                 10.50
# 270954             8           33.04                  1.60
#
#         Volume Sold (Gallons)
# 0                        2.38
# 1                        0.40
# 2                        6.34
# 3                        2.77
# 4                        5.55
# 5                        2.77
# 6                        0.59
# 7                        0.92
# 8                        0.79
# 9                        0.53
# 10                       1.19
# 11                       2.77
# 12                       0.46
# 13                       2.38
# 14                       3.17
# 15                       0.79
# 16                       2.54
# 17                       2.38
# 18                       6.34
# 19                       2.77
# 20                       0.40
# 21                       2.38
# 22                       2.38
# 23                       2.38
# 24                       2.38
# 25                       6.34
# 26                       0.08
# 27                       0.59
# 28                       2.77
# 29                       0.13
# ...                       ...
# 270925                   0.79
# 270926                   1.19
# 270927                   3.17
# 270928                   4.76
# 270929                   0.79
# 270930                   1.19
# 270931                   2.38
# 270932                   0.92
# 270933                   0.59
# 270934                   0.92
# 270935                   0.59
# 270936                   2.38
# 270937                   0.20
# 270938                   0.30
# 270939                   0.79
# 270940                   0.79
# 270941                   2.77
# 270942                   2.38
# 270943                   0.13
# 270944                   0.40
# 270945                   1.27
# 270946                   0.79
# 270947                   0.59
# 270948                   0.59
# 270949                   0.79
# 270950                   0.32
# 270951                   0.59
# 270952                   1.19
# 270953                   2.77
# 270954                   0.42
#
# [270955 rows x 18 columns]

# %%
# Convert dates
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0        2015-11-04
# 1        2016-03-02
# 2        2016-02-11
# 3        2016-02-03
# 4        2015-08-18
# 5        2015-04-20
# 6        2015-08-05
# 7        2015-06-25
# 8        2016-01-04
# 9        2015-11-10
# 10       2015-09-28
# 11       2015-10-28
# 12       2015-01-22
# 13       2016-02-29
# 14       2016-01-04
# 15       2015-06-10
# 16       2016-02-25
# 17       2015-12-29
# 18       2015-12-26
# 19       2015-03-04
# 20       2015-01-16
# 21       2015-01-13
# 22       2015-03-24
# 23       2015-11-12
# 24       2016-03-14
# 25       2015-02-03
# 26       2015-11-23
# 27       2015-04-21
# 28       2015-12-01
# 29       2015-01-14
#             ...
# 270925   2015-01-05
# 270926   2015-12-26
# 270927   2015-08-31
# 270928   2015-10-07
# 270929   2016-01-25
# 270930   2015-10-13
# 270931   2015-05-26
# 270932   2015-06-18
# 270933   2015-02-26
# 270934   2015-03-18
# 270935   2015-06-08
# 270936   2015-03-31
# 270937   2015-01-27
# 270938   2015-04-29
# 270939   2015-05-04
# 270940   2015-01-21
# 270941   2015-02-09
# 270942   2015-06-15
# 270943   2015-10-21
# 270944   2016-03-22
# 270945   2015-06-11
# 270946   2015-11-24
# 270947   2015-05-12
# 270948   2015-04-08
# 270949   2015-07-21
# 270950   2015-12-22
# 270951   2015-11-04
# 270952   2015-10-20
# 270953   2015-11-20
# 270954   2015-01-27
# Name: Date, dtype: datetime64[ns]

# %%
# Drop or replace bad values

# Convert integers
df['County Number'] = df['County Number'].fillna(0).astype(int)
df.dropna()
# Out:
#              Date  Store Number         City Zip Code  County Number  \
# 22111  2015-01-08          2106  CEDAR FALLS    50613              7
# 47659  2015-01-08          2106  CEDAR FALLS    50613              7
# 65214  2015-01-08          2106  CEDAR FALLS    50613              7
# 66346  2015-01-08          2106  CEDAR FALLS    50613              7
# 80570  2015-01-08          2106  CEDAR FALLS    50613              7
# 105659 2015-01-08          2106  CEDAR FALLS    50613              7
# 110707 2015-01-08          2106  CEDAR FALLS    50613              7
# 130957 2015-01-08          2106  CEDAR FALLS    50613              7
# 144321 2015-01-08          2106  CEDAR FALLS    50613              7
# 165212 2015-01-08          2106  CEDAR FALLS    50613              7
# 175048 2015-01-08          2106  CEDAR FALLS    50613              7
# 193161 2015-01-08          2106  CEDAR FALLS    50613              7
# 223428 2015-01-08          2106  CEDAR FALLS    50613              7
# 238277 2015-01-08          2106  CEDAR FALLS    50613              7
# 13533  2015-01-15          2106  CEDAR FALLS    50613              7
# 22526  2015-01-15          2106  CEDAR FALLS    50613              7
# 130870 2015-01-15          2106  CEDAR FALLS    50613              7
# 158419 2015-01-15          2106  CEDAR FALLS    50613              7
# 187130 2015-01-15          2106  CEDAR FALLS    50613              7
# 199964 2015-01-15          2106  CEDAR FALLS    50613              7
# 213003 2015-01-15          2106  CEDAR FALLS    50613              7
# 224597 2015-01-15          2106  CEDAR FALLS    50613              7
# 2512   2015-01-22          2106  CEDAR FALLS    50613              7
# 36665  2015-01-22          2106  CEDAR FALLS    50613              7
# 57177  2015-01-22          2106  CEDAR FALLS    50613              7
# 58530  2015-01-22          2106  CEDAR FALLS    50613              7
# 70401  2015-01-22          2106  CEDAR FALLS    50613              7
# 77078  2015-01-22          2106  CEDAR FALLS    50613              7
# 84913  2015-01-22          2106  CEDAR FALLS    50613              7
# 88407  2015-01-22          2106  CEDAR FALLS    50613              7
# ...           ...           ...          ...      ...            ...
# 17890  2016-01-07          9002     LECLAIRE    52753             82
# 121038 2016-01-07          9002     LECLAIRE    52753             82
# 35520  2016-01-14          9002     LECLAIRE    52753             82
# 154818 2016-01-21          9002     LECLAIRE    52753             82
# 203593 2016-03-10          9002     LECLAIRE    52753             82
# 16295  2015-01-20          9010      NORWALK    50211             91
1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 178774      Warren  1051010.0             AMERICAN GRAPE BRANDIES
# 244748      Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 137593      Warren  1011100.0                    BLENDED WHISKIES
# 209820      Warren  1011100.0                    BLENDED WHISKIES
# 269367      Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 172628      Warren  1011100.0                    BLENDED WHISKIES
# 141678      Warren  1081600.0                     WHISKEY LIQUEUR
# 128323      Warren  1011100.0                    BLENDED WHISKIES
# 91949       Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 181268      Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 49892       Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 71007       Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 28640       Warren  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 105091      Warren  1031080.0                      VODKA 80 PROOF
# 42383       Warren  1011100.0                    BLENDED WHISKIES
# 28118       Warren  1011100.0                    BLENDED WHISKIES
# 100716      Warren  1011100.0                    BLENDED WHISKIES
# 89110       Warren  1031080.0                      VODKA 80 PROOF
# 236012      Warren  1101100.0                    AMERICAN ALCOHOL
# 139261     Dubuque  1062310.0                          SPICED RUM
# 107866     Carroll  1011200.0           STRAIGHT BOURBON WHISKIES
#
#         Vendor Number  Item Number       ...        Bottle Volume (ml)  \
# 22111              35        43127       ...                      1000
# 47659             410        88296       ...                       750
# 65214             259        43026       ...                       750
# 66346             305        73055       ...                       750
# 80570             434        46351       ...                      1000
# 105659            434        34546       ...                       750
# 110707            322        75214       ...                       750
# 130957             65        82637       ...                      1000
# 144321            260        11297       ...                      1000
# 165212            434        36307       ...                      1000
# 175048            192        65257       ...                      1000
# 193161            260        11296       ...                       750
# 223428             55        29287       ...                      1000
# 238277            380        41694       ...                      1000
# 13533             240        15940       ...                       750
# 22526             421        86637       ...                      1000
# 130870            380        84636       ...                       750
# 158419            395        89197       ...                      1000
# 187130             55        35318       ...                      1750
# 199964             55        35317       ...                      1000
# 213003            434        36667       ...                      1000
# 224597            370        42717       ...                      1000
# 2512              434        30527       ...                      1000
# 36665             370        32231       ...                       500
# 57177             260        68037       ...                      1000
# 58530             434        76526       ...                       750
# 70401             421        69636       ...                       750
# 77078             259       902929       ...                       750
# 84913             260        10812       ...                       750
# 88407             260        69947       ...                      1000
# ...               ...          ...       ...                       ...
# 17890             306        37642       ...                       750
# 121038            306        37640       ...                       750
# 35520             306        31990       ...                       750
# 154818            306        27535       ...                       375
# 203593            306        27535       ...                       375
# 16295              86        75740       ...                       750
# 267581             86        27323       ...                       750
# 127223             86        27318       ...                       750
# 135891             86        77723       ...                       750
# 178774             86        53920       ...                       375
# 244748             86        77724       ...                       750
# 137593             86        27323       ...                       750
# 209820             86        27318       ...                       750
# 269367             86        86661       ...                       750
# 172628             86        27323       ...                       750
# 141678             86        75740       ...                       750
# 128323             86        27323       ...                       750
# 91949              86        86661       ...                       750
# 181268             86          322       ...                       200
# 49892              86          322       ...                       200
# 71007              86        77724       ...                       750
# 28640              86        86661       ...                       750
# 105091            154        36447       ...                       750
# 42383             154        27255       ...                       750
# 28118             154        27255       ...                       750
# 100716            154        27629       ...                       750
# 89110             195        38058       ...                      1000
# 236012            154        77284       ...                       750
# 139261            207        46686       ...                       750
# 107866            116        26996       ...                       750
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 22111                9.50                14.25            36          513.00
# 47659               27.00                40.50            12          486.00
# 65214                5.78                 8.67            12          104.04
# 66346               12.50                18.75            12          225.00
# 80570                4.34                 6.51            12           78.12
# 105659               7.86                11.79            12          141.48
# 110707              10.00                15.00            12          180.00
# 130957               7.62                11.43            12          137.16
# 144321              18.50                27.75            36          999.00
# 165212               4.05                 6.08            12           72.96
# 175048              15.54                23.31            72         1678.32
# 193161              15.00                22.50            12          270.00
# 223428               3.92                 5.88            12           70.56
# 238277               7.50                11.25            12          135.00
# 13533               14.38                21.57            12          258.84
# 22526                3.01                 4.52            12           54.24
# 130870               7.45                11.18            12          134.16
# 158419              12.50                18.75            48          900.00
# 187130               6.92                10.38             6           62.28
# 199964               3.97                 5.96           120          715.20
# 213003               4.32                 6.48            12           77.76
# 224597              10.49                15.74            36          566.64
# 2512                 4.23                 6.35            12           76.20
# 36665                3.30                 4.95             1            4.95
# 57177               17.25                25.88            12          310.56
# 58530                5.30                 7.95            12           95.40
# 70401                8.67                13.01            12          156.12
# 77078                6.63                 9.95            60          597.00
# 84913               37.48                56.22             6          337.32
# 88407               15.75                23.63            12          283.56
# ...                   ...                  ...           ...             ...
# 17890               10.17                15.26            24          366.24
# 121038              14.02                21.03            12          252.36
# 35520               16.17                24.26            18          436.68
# 154818               9.09                13.64            12          163.68
# 203593               9.09                13.64            12          163.68
# 16295               13.29                19.94            24          478.56
# 267581              15.59                23.39            24          561.36
# 127223              13.87                20.81            24          499.44
# 135891              13.29                19.94            24          478.56
# 178774               8.45                12.68            24          304.32
# 244748              13.29                19.94            24          478.56
# 137593              15.59                23.39            24          561.36
# 209820              13.87                20.81            24          499.44
# 269367               9.86                14.79            24          354.96
# 172628              15.59                23.39            12          280.68
# 141678              13.29                19.94            12          239.28
# 128323              15.59                23.39            12          280.68
# 91949                9.86                14.79            12          177.48
# 181268               3.00                 4.50            48          216.00
# 49892                3.00                 4.50            24          108.00
# 71007               13.29                19.94            12          239.28
# 28640                9.86                14.79            12          177.48
# 105091              12.54                18.81            36          677.16
# 42383                9.17                13.76            12          165.12
# 28118                3.09                 4.64           120          556.80
# 100716               9.09                13.64            60          818.40
# 89110                7.18                10.77            12          129.24
# 236012               6.45                 9.68            24          232.32
# 139261              14.30                21.45           300         6435.00
# 107866              17.59                26.39            24          633.36
#
#         Volume Sold (Liters)  Volume Sold (Gallons)  Margin  Price per Bottle  \
# 22111                   36.0                   9.51    4.75             14.25
# 47659                    9.0                   2.38   13.50             40.50
# 65214                    9.0                   2.38    2.89              8.67
# 66346                    9.0                   2.38    6.25             18.75
# 80570                   12.0                   3.17    2.17              6.51
# 105659                   9.0                   2.38    3.93             11.79
# 110707                   9.0                   2.38    5.00             15.00
# 130957                  12.0                   3.17    3.81             11.43
# 144321                  36.0                   9.51    9.25             27.75
# 165212                  12.0                   3.17    2.03              6.08
# 127223         1.156111
# 135891         1.107778
# 178774         1.408889
# 244748         1.107778
# 137593         1.299444
# 209820         1.156111
# 269367         0.821667
# 172628         2.598889
# 141678         2.215556
# 128323         2.598889
# 91949          1.643333
# 181268         0.468750
# 49892          0.937500
# 71007          2.215556
# 28640          1.643333
# 105091         0.696667
# 42383          1.528889
# 28118          0.051556
# 100716         0.303111
# 89110          0.897500
# 236012         0.537778
# 139261         0.095333
# 107866         1.466111
#
# [269258 rows x 21 columns]

# %%
StoreDates = pd.DataFrame(columns = ['Date', 'Store'])
StoreDates['Date'] = df['Date']
StoreDates['Store'] = df['Store Number']
StoreNumbers = (StoreDates['Store'].unique())
GroupedByStore = StoreDates.groupby(by = ['Store'], as_index = False).count()
GroupedByStore
# Out:
#       Store  Date
# 0      2106   654
# 1      2113   184
# 2      2130   509
# 3      2152   171
# 4      2178   295
# 5      2190  1626
# 6      2191   739
# 7      2200   485
# 8      2205   288
# 9      2228   306
# 10     2233   290
# 11     2238    71
# 12     2248   560
# 13     2285   358
# 14     2290  1041
# 15     2327   234
# 16     2353   414
# 17     2367    45
# 18     2413   606
# 19     2445   200
# 20     2448   505
# 21     2459   133
# 22     2460   397
# 23     2465   461
# 24     2475   106
# 25     2478   107
# 26     2487   409
# 27     2498    76
# 28     2500  1521
# 29     2501  1553
# ...     ...   ...
# 1370   5211    19
# 1371   5212    28
# 1372   5213    13
# 1373   5214    12
# 1374   5215    56
# 1375   5216     3
# 1376   5217     6
# 1377   5218     2
# 1378   5220    61
# 1379   5222    33
# 1380   5223     3
# 1381   5224    20
# 1382   5225    14
# 1383   5226    13
# 1384   5227    27
# 1385   5229     5
# 1386   5230    65
# 1387   5232     4
# 1388   5233     4
# 1389   5234     3
# 1390   5236    49
# 1391   5237     6
# 1392   5240     7
# 1393   5247     7
# 1394   9001    24
# 1395   9002    49
# 1396   9010    17
# 1397   9013     6
# 1398   9018     1
# 1399   9023     1
#
# [1400 rows x 2 columns]

# %% [markdown]
# ## Filter the Data
#
# Some stores may have opened or closed in 2015. These data points will heavily skew our models, so we need to filter them out or find a way to deal with them.
#
# You'll need to provide a summary in your project report about these data points. You may also consider using the monthly sales in your model and including other information (number of months or days each store is open) in your data to handle these unusual cases.
#
# Let's record the first and last sales dates for each store. We'll save this information for later when we fit our models.

# %%
# Determine which stores were open all of 2015
# Find the first and last sales date.


# Filter out stores that opened or closed throughout the year
# You may want to save this step until you start modelling
# Out:
# /Users/davidswan/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-8406a8428904> in <module>()
#       2 # Find the first and last sales date.
#       3
# ----> 4 df.sort(df[['Date']])
#       5 # Filter out stores that opened or closed throughout the year
#       6 # You may want to save this step until you start modelling
#
# /Users/davidswan/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in sort(self, columns, axis, ascending, inplace, kind, na_position)
#    3216         return self.sort_values(by=columns, axis=axis, ascending=ascending,
#    3217                                 inplace=inplace, kind=kind,
# -> 3218                                 na_position=na_position)
#    3219
#    3220     @Appender(_shared_docs['sort_index'] % _shared_doc_kwargs)
#
# /Users/davidswan/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3143
#    3144             by = by[0]
# -> 3145             k = self[by].values
#    3146             if k.ndim == 2:
#    3147
#
# /Users/davidswan/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1986             return self._getitem_array(key)
#    1987         elif isinstance(key, DataFrame):
# -> 1988             return self._getitem_frame(key)
#    1989         elif is_mi_columns:
#    1990             return self._getitem_multilevel(key)
#
# /Users/davidswan/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_frame(self, key)
#    2061     def _getitem_frame(self, key):
#    2062         if key.values.size and not com.is_bool_dtype(key.values):
# -> 2063             raise ValueError('Must pass DataFrame with boolean values only')
#    2064         return self.where(key)
#    2065
#
# ValueError: Must pass DataFrame with boolean values only

# %% [markdown]
# ## Compute New Columns and Tables
#
# Since we're trying to predict sales and/or profits, we'll want to compute some intermediate data. There are a lot of ways to do thisand good use of pandas is crucial. For example, for each transaction we may want to know:
# * margin, retail cost minus bottle cost
# * price per bottle
# * price per liter
#
# We'll need to make a new dataframe that indexes quantities by store:
# * sales per store for all of 2015
# * sales per store for Q1 2015
# * sales per store for Q1 2016
# * total volumes sold
# * mean transaction revenue, gross margin, price per bottle, price per liter, etc.
# * average sales per day
# * number of days open
#
# Make sure to retain other variables that we'll want to use to build our models, such as zip code, county number, city, etc. We recommend that you spend some time thinking about the model you may want to fit and computing enough of the suggested quantities to give you a few options.
#
# Bonus tasks:
# * Restrict your attention to stores that were open for all of 2015 and Q1 2016. Stores that opened or closed in 2015 will introduce outliers into your data.
# * For each transaction we have the item category. You may be able to determine the store type (primarily wine, liquor, all types of alcohol, etc.) by the most common transaction category for each store. This could be a useful categorical variable for modelling.

# %%
df.columns
# Out:
# Index([u'Date', u'Store Number', u'City', u'Zip Code', u'County Number',
#        u'County', u'Category', u'Category Name', u'Vendor Number',
#        u'Item Number', u'Item Description', u'Bottle Volume (ml)',
#        u'State Bottle Cost', u'State Bottle Retail', u'Bottles Sold',
#        u'Sale (Dollars)', u'Volume Sold (Liters)', u'Volume Sold (Gallons)',
#        u'Margin'],
#       dtype='object')

# %%
# Margin and Price per liter
df['Margin'] = df['State Bottle Retail'] - df['State Bottle Cost']
df['Price per Liter'] = df['State Bottle Retail']/df['Volume Sold (Liters)']
df.head()
# Out:
#             Date  Store Number         City Zip Code  County Number  \
# 22111 2015-01-08          2106  CEDAR FALLS    50613              7
# 47659 2015-01-08          2106  CEDAR FALLS    50613              7
# 65214 2015-01-08          2106  CEDAR FALLS    50613              7
# 66346 2015-01-08          2106  CEDAR FALLS    50613              7
# 80570 2015-01-08          2106  CEDAR FALLS    50613              7
#
#            County   Category                     Category Name  Vendor Number  \
# 22111  Black Hawk  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM             35
# 47659  Black Hawk  1022100.0                           TEQUILA            410
# 65214  Black Hawk  1062310.0                        SPICED RUM            259
# 66346  Black Hawk  1081200.0                    CREAM LIQUEURS            305
# 80570  Black Hawk  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM            434
#
#        Item Number       ...        Bottle Volume (ml)  State Bottle Cost  \
# 22111        43127       ...                      1000               9.50
# 47659        88296       ...                       750              27.00
# 65214        43026       ...                       750               5.78
# 66346        73055       ...                       750              12.50
# 80570        46351       ...                      1000               4.34
#
#        State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 22111                14.25            36          513.00
# 47659                40.50            12          486.00
# 65214                 8.67            12          104.04
# 66346                18.75            12          225.00
# 80570                 6.51            12           78.12
#
#        Volume Sold (Liters)  Volume Sold (Gallons)  Margin  Price per Bottle  \
# 22111                  36.0                   9.51    4.75             14.25
# 47659                   9.0                   2.38   13.50             40.50
# 65214                   9.0                   2.38    2.89              8.67
# 66346                   9.0                   2.38    6.25             18.75
# 80570                  12.0                   3.17    2.17              6.51
#
#        Price per Liter
# 22111         0.395833
# 47659         4.500000
# 65214         0.963333
# 66346         2.083333
# 80570         0.542500
#
# [5 rows x 21 columns]

# %%
# Sales per store, 2015

# Filter by our start and end dates
df.sort_values(by=["Store Number", "Date"], inplace=True)
start_date = pd.Timestamp("20150101")
end_date = pd.Timestamp("20151231")
mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
sales = df[mask]

# Group by store name
sales = sales.groupby(by=["Store Number"], as_index=False)
# Compute sums, means
sales = sales.agg({"Sale (Dollars)": [np.sum, np.mean],
                   "Volume Sold (Liters)": [np.sum, np.mean],
                   "Margin": np.mean,
                   "Price per Liter": np.mean,
                   "Zip Code": lambda x: x.iloc[0], # just extract once, should be the same
                   "City": lambda x: x.iloc[0],
                   "County Number": lambda x: x.iloc[0]})
# Collapse the column indices
sales.columns = [' '.join(col).strip() for col in sales.columns.values]
# Rename columns

# Quick check
sales
# Out:
#       Store Number    City <lambda>  Sale (Dollars) sum  Sale (Dollars) mean  \
# 0             2106      CEDAR FALLS           146326.22           277.658861
# 1             2113           GOWRIE             9310.22            63.334830
# 2             2130         WATERLOO           111871.43           285.386301
# 3             2152         ROCKWELL             7721.08            54.759433
# 4             2178           WAUKON            24324.18           102.633671
# 5             2190       DES MOINES           121689.06            92.539209
# 6             2191           KEOKUK           125093.49           209.888406
# 7             2200         SAC CITY            22811.55            56.604342
# 8             2205         CLARINDA            24681.39            85.699271
# 9             2228        WINTERSET            17462.07            72.758625
# 10            2233      SPIRIT LAKE            29553.34           122.627967
# 11            2238          ALTOONA            11762.56           192.828852
# 12            2248       DES MOINES            67682.06           147.134913
# 13            2285        IOWA CITY            76927.11           251.395784
# 14            2290       STORM LAKE            56514.43            72.084732
# 15            2327          CORNING            10245.14            54.207090
# 16            2353           CRESCO            54000.55           148.761846
# 17            2367       SHENANDOAH             5010.83           111.351778
# 18            2413          DUBUQUE            90065.02           187.245364
# 19            2445          OAKLAND             7189.48            42.043743
# 20            2448        INDIANOLA            17740.70            43.164720
# 21            2459   GUTHRIE CENTER             7352.33            68.077130
# 22            2460          HAMPTON            33731.76           101.296577
# 23            2465          DUBUQUE            25831.80            66.065985
# 24            2475        WEST BEND            10681.07           144.338784
# 25            2478          ALTOONA            19840.65           230.705233
# 26            2487          ANAMOSA            28900.96            70.662494
# 27            2498        ARLINGTON             2259.67            38.959828
# 28            2500             AMES           149121.63           126.481450
# 29            2501             AMES           144833.66           113.062966
# ...            ...              ...                 ...                  ...
# 1342          5180          OELWEIN             2239.44            62.206667
# 1343          5181           DENVER              963.04            87.549091
# 1344          5182   COUNCIL BLUFFS             2612.94           145.163333
# 1345          5183          CASCADE              916.80           152.800000
# 1346          5185       CORALVILLE             1077.39            82.876154
# 1347          5186       WEST UNION              298.86            42.694286
# 1348          5187             AMES             4239.11            51.073614
# 1349          5188       SIOUX CITY             1887.73           111.042941
# 1350          5189  WEST DES MOINES              604.20           151.050000
# 1351          5190          WALFORD             1161.73            77.448667
# 1352          5191   GUTHRIE CENTER              303.90            75.975000
# 1353          5192           ROBINS               90.00            90.000000
# 1354          5193        LOHRVILLE              139.50            46.500000
# 1355          5196       CORALVILLE              682.85            42.678125
# 1356          5198        DAVENPORT             3985.06            62.266563
# 1357          5199          OELWEIN             2046.22           127.888750
# 1358          5201          DUBUQUE              289.78            96.593333
# 1359          5203      COON RAPIDS              928.49            92.849000
# 1360          5204       BURLINGTON              790.44            37.640000
# 1361          5205          GLIDDEN               39.02            19.510000
# 1362          5206    GRUNDY CENTER              500.90            62.612500
# 1363          5207     CEDAR RAPIDS             3197.95           127.918000
# 1364          5212       MASON CITY              504.54            72.077143
# 1365          5213         MONTROSE              180.00           180.000000
# 1366          5215        LE CLAIRE               56.03            28.015000
# 1367          9001          SWISHER            28208.52          1226.457391
# 1368          9002         LECLAIRE            37700.52           856.830000
# 1369          9010          NORWALK             5757.96           359.872500
# 1370          9013          Cumming             2217.48           554.370000
# 1371          9018          Dubuque             6435.00          6435.000000
#
#       County Number <lambda>  Price per Liter mean Zip Code <lambda>  \
# 0                          7              2.788873             50613
# 1                         94             10.042565             50543
# 2                          7              1.784414             50703
# 3                         17              7.270728             50469
# 4                          3              6.995544             52172
# 5                         77             10.768266             50314
# 6                         56              8.401970             52632
# 7                         81              8.910528             50583
# 8                         73              7.835454             51632
# 9                         61             10.861604             50273
# 10                        30              7.868196             51360
# 11                        77              8.867424             50009
# 12                        77              7.240071             50312
# 13                        52              5.440805             52240
# 14                        11              9.405341             50588
# 15                         2              8.482071             50841
# 16                        45              5.551418             52136
# 17                        73              3.634870             51601
# 18                        31              2.544021             52001
# 19                        78              8.101695             51560
# 20                        91             11.018320             50125
# 21                        39              3.923289             50115
# 22                        35              5.995234             50441
# 23                        31             11.025436             52003
# 24                        55              3.943442             50597
# 25                        77              6.374815             50009
# 26                        53              7.818459             52205
# 27                        33              5.567692             50606
# 28                        85              7.401615             50010
# 29                        85              5.566331             50010
# ...                      ...                   ...               ...
# 1342                      33              9.376176             50662
# 1343                       9              7.343611             50622
# 1344                      78              1.429863             51501
# 1345                      31              1.128720             52033
# 1346                      52              4.574444             52241
# 1347                      33              5.985686             52175
# 1348                      85              9.315018             50010
# 1349                      97              3.839963             51101
# 1350                      77              1.728571             50266
# 1351                      57              4.703735             52351
# 1352                      39              3.002778             50115
# 1353                      57              3.333333             52328
# 1354                      13              4.137778             51453
# 1355                      52              9.570032             52241
# 1356                      82              6.409441             52803
# 1357                      33              5.475588             50662
# 1358                      31              4.571363             52001
# 1359                      14              7.454440             50058
# 1360                      29             12.185013             52601
# 1361                      14              6.000000             51443
# 1362                      38              7.272361             50638
# 1363                      57              9.373462             52404
# 1364                      17              3.457415             50401
# 1365                      56              0.390625             52639
# 1366                      82             25.883333             52753
# 1367                      52              2.732211             52338
# 1368                      82              1.687640             52753
# 1369                      91              1.446467             50211
# 1370                      91              0.645056             50061
# 1371                      31              0.095333             52001
#
#       Volume Sold (Liters) sum  Volume Sold (Liters) mean  Margin mean
# 0                      9731.85                  18.466509     5.166319
# 1                       659.85                   4.488776     5.445102
# 2                      6891.37                  17.580026     4.925842
# 3                       633.37                   4.491986     4.322624
# 4                      1917.12                   8.089114     4.868861
# 5                      6322.17                   4.807734     5.774259
# 6                      8053.32                  13.512282     5.778087
# 7                      1817.24                   4.509280     5.620868
# 8                      1556.91                   5.405937     5.098785
# 9                      1367.65                   5.698542     4.875417
# 10                     2480.69                  10.293320     5.862116
# 11                      705.75                  11.569672     6.159016
# 12                     2815.35                   6.120326     7.534739
# 13                     3860.35                  12.615523     6.829608
# 14                     3626.20                   4.625255     5.301556
# 15                      822.28                   4.350688     5.099841
# 16                     4504.65                  12.409504     5.153719
# 17                      346.75                   7.705556     4.760000
# 18                     6261.29                  13.017235     5.026549
# 19                      571.79                   3.343801     4.949474
# 20                     1245.53                   3.030487     5.049148
# 21                      607.24                   5.622593     4.026204
# 22                     2782.46                   8.355736     5.131952
# 23                     1713.20                   4.381586     5.897928
# 24                     1044.94                  14.120811     5.630676
# 25                     1038.00                  12.069767     7.013721
# 26                     2547.85                   6.229462     4.639169
# 27                      230.12                   3.967586     3.105517
# 28                    10039.15                   8.514970     5.211264
# 29                     9959.40                   7.774707     5.003607
# ...                        ...                        ...          ...
# 1342                    175.25                   4.868056     3.971389
# 1343                     65.30                   5.936364     3.607273
# 1344                    164.70                   9.150000     3.376111
# 1345                     61.80                  10.300000     3.811667
# 1346                     73.00                   5.615385     3.637692
# 1347                     16.49                   2.355714     3.110000
# 1348                    218.31                   2.630241     4.608554
# 1349                     96.40                   5.670588     4.421176
# 1350                     39.00                   9.750000     5.582500
# 1351                     69.75                   4.650000     4.940667
# 1352                     19.50                   4.875000     4.222500
# 1353                      4.50                   4.500000     5.000000
# 1354                      9.00                   3.000000     3.793333
# 1355                     37.97                   2.373125     4.601875
# 1356                    200.43                   3.131719     4.159063
# 1357                    148.80                   9.300000     4.811875
# 1358                      8.63                   2.876667     3.960000
# 1359                     79.50                   7.950000     5.493000
# 1360                     57.10                   2.719048     3.183333
# 1361                      3.50                   1.750000     3.335000
# 1362                     26.35                   3.293750     4.075000
# 1363                    135.06                   5.402400     4.733600
# 1364                     36.75                   5.250000     3.925714
# 1365                      9.60                   9.600000     1.250000
# 1366                      1.80                   0.900000     5.590000
# 1367                    639.00                  27.782609     9.473913
# 1368                   1242.00                  28.227273     6.871591
# 1369                    212.40                  13.275000     5.963750
# 1370                    171.00                  42.750000     4.240000
# 1371                    225.00                 225.000000     7.150000
#
# [1372 rows x 10 columns]

# %%
# Q1 sales, may want to also use aggregate as above to have more columns (means, etc.)

# Sales 2015  Q1

# Sales 2016 Q1

# %% [markdown]
# Proceed with any calculations that you need for your models, such as grouping
# sales by zip code, most common vendor number per store, etc. Once you have finished adding columns, be sure to save the dataframe.

# %%
# Compute more things
# ...

# %%
# Save this dataframe

# Let's add the dates computed above to this data.
sales["First Date"] = dates['Date amin']
sales["Last Date"] = dates['Date amax']

sales.to_csv("sales.csv")
