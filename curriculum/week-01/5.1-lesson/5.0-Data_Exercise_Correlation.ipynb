# %% [markdown]
# $$ \rho_{X,Y} = \frac{cov ( X,Y) }{\sigma _{X}\sigma_{Y}} $$

# %% [markdown]
# The dataset provided contains information about MPG and CO2 emission of 2015 cars. Given the dataset and pandas, please answer the following questions:

# %% [markdown]
# (1)	What car(s) have the highest MPG_COMBINED?

# %%
import pandas as pd
import matplotlib.pyplot as plt

excel_data = []

x1 = pd.ExcelFile('/Users/davidswan/Downloads/cars_2015_mpg.xlsx')
x1.sheet_names
df = x1.parse('MPG')
df[df['MPG_COMBINED'] == df['MPG_COMBINED'].max()]
#print df[df['MPG_COMBINED'] == 50]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
(2)	Which car(s) produce the least amount of CO2_COMBINED?

# %%
df[df['CO2_COMBINED'] == df['CO2_COMBINED'].min()]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
(3) What is the correlation between VOLUME and the MPG_CITY?

# %%
df['VOLUME'].corr(df['MPG_CITY'])
# Out:
# -0.76431067054606661

# %%
(4) What is the correlation between MPG_CITY and MPG_HWY?

# %%
df.corr()
# Out:
#               YEAR    VOLUME  CYLINDERS     GEARS  MPG_CITY   MGP_HWY  \
# YEAR           NaN       NaN        NaN       NaN       NaN       NaN
# VOLUME         NaN  1.000000   0.925112  0.266896 -0.764311 -0.783647
# CYLINDERS      NaN  0.925112   1.000000  0.323175 -0.740763 -0.739675
# GEARS          NaN  0.266896   0.323175  1.000000 -0.399422 -0.235804
# MPG_CITY       NaN -0.764311  -0.740763 -0.399422  1.000000  0.910289
# MGP_HWY        NaN -0.783647  -0.739675 -0.235804  0.910289  1.000000
# MPG_COMBINED   NaN -0.795330  -0.763085 -0.346347  0.985509  0.961812
# CO2_CITY       NaN  0.867037   0.851798  0.304054 -0.918436 -0.905335
# CO2_HWY        NaN  0.814849   0.770175  0.183520 -0.849205 -0.949975
# CO2_COMBINED   NaN  0.860799   0.835214  0.267232 -0.906508 -0.931952
#
#               MPG_COMBINED  CO2_CITY   CO2_HWY  CO2_COMBINED
# YEAR                   NaN       NaN       NaN           NaN
# VOLUME           -0.795330  0.867037  0.814849      0.860799
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt    #import matplotlib libary
# %matplotlib inline
y = df['VOLUME']                     #define some data
x = df['CYLINDERS']
plt.scatter(x, y)                      #plot data
plt.show()                         #show plot

# %%
print df.ix[45]
df.ix[[45]]
df.shape
# Out:
# YEAR                               2015
# MANUFACTURER                     Jaguar
# MODEL           F-TYPE V8 S Convertible
# VOLUME                                5
# CYLINDERS                             8
# GEARS                                 8
# FWD_RWD                               R
# DRIVE_DESCR         2-Wheel Drive, Rear
# MPG_CITY                             16
# MGP_HWY                              23
# MPG_COMBINED                         18
# CO2_CITY                            570
# CO2_HWY                             386
# CO2_COMBINED                        487
# Name: 45, dtype: object
# (1232, 14)

# %%
df.describe()
# Out:
#          YEAR       VOLUME    CYLINDERS        GEARS     MPG_CITY  \
# count  1232.0  1232.000000  1232.000000  1232.000000  1232.000000
# mean   2015.0     3.264367     5.729708     6.397727    20.153409
# std       0.0     1.384939     1.844700     1.408202     5.527423
# min    2015.0     1.000000     3.000000     1.000000     8.000000
# 25%    2015.0     2.000000     4.000000     6.000000    16.000000
# 50%    2015.0     3.000000     6.000000     6.000000    19.000000
# 75%    2015.0     3.800000     6.000000     7.000000    23.000000
# max    2015.0     8.400000    16.000000     9.000000    53.000000
#
#            MGP_HWY  MPG_COMBINED     CO2_CITY      CO2_HWY  CO2_COMBINED
# count  1232.000000   1232.000000  1232.000000  1232.000000   1232.000000
# mean     27.928571     22.965909   473.239448   335.655844    411.293831
# std       6.182029      5.685114   122.640050    76.549162    100.460943
# min      14.000000     10.000000   168.000000   177.000000    178.000000
# ...

# %%
df.sort(columns = ['VOLUME', 'CYLINDERS'], ascending = False)
# Out:
# /Users/davidswan/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#       YEAR                    MANUFACTURER                       MODEL  \
# 27    2015                           Dodge                   Viper SRT
# 22    2015                         Bugatti                      Veyron
# 316   2015                       Chevrolet                      CAMARO
# 468   2015                         Bentley                    Mulsanne
# 411   2015  Rolls-Royce Motor Cars Limited               Phantom Coupe
# 412   2015  Rolls-Royce Motor Cars Limited      Phantom Drophead Coupe
# 749   2015  Rolls-Royce Motor Cars Limited                     Phantom
# 750   2015  Rolls-Royce Motor Cars Limited                 Phantom EWB
# 625   2015  Rolls-Royce Motor Cars Limited                      Wraith
# 747   2015  Rolls-Royce Motor Cars Limited                       Ghost
# ...

# %%
df.groupby(['CYLINDERS'])['MPG_CITY'].mean()
# Out:
# CYLINDERS
# 3     31.181818
# 4     24.663327
# 5     19.500000
# 6     18.582367
# 8     14.545455
# 10    12.666667
# 12    12.148148
# 16     8.000000
# Name: MPG_CITY, dtype: float64

# %%
df.groupby(['MANUFACTURER'])['VOLUME'].mean()
# Out:
# MANUFACTURER
# Acura                               3.130000
# Alfa Romeo                          1.800000
# Aston Martin Lagonda Ltd            5.210000
# Audi                                3.070909
# BMW                                 3.113559
# Bentley                             5.100000
# Bugatti                             8.000000
# Buick                               2.525000
# CHEVROLET                           2.000000
# Cadillac                            4.203571
# Chevrolet                           3.830682
# Chrysler                            3.576923
# Dodge                               4.208571
# FIAT                                1.400000
# Ferrari North America, Inc.         4.928571
# Ford                                2.744595
# GMC                                 4.892157
# HYUNDAI MOTOR COMPANY               2.483721
# Honda                               2.400000
# INFINITI                            3.826667
# ...

# %%
# %matplotlib inline
df.groupby(['CYLINDERS'])['MPG_CITY'].mean().plot.bar()

# %%
df_ = df.iloc[:,1::]
df_.iloc[:,4].plot.hist(alpha = .5)

# %%
data = []
with open('FILEPATH') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
f.close()
