# %% [markdown]
# $$ \rho_{X,Y} = \frac{cov ( X,Y) }{\sigma _{X}\sigma_{Y}} $$

# %% [markdown]
# The dataset provided contains information about MPG and CO2 emission of 2015 cars. Given the dataset and pandas, please answer the following questions:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xl = pd.ExcelFile("/Users/jam3jam/Downloads/cars_2015_mpg.xlsx")
xl.sheet_names
df = xl.parse("MPG")
print df.head()
# Out:
#    YEAR              MANUFACTURER          MODEL  VOLUME  CYLINDERS  GEARS  \
# 0  2015                Alfa Romeo             4C     1.8          4      6
# 1  2015  Aston Martin Lagonda Ltd  V12 Vantage S     6.0         12      7
# 2  2015  Aston Martin Lagonda Ltd     V8 Vantage     4.7          8      7
# 3  2015  Aston Martin Lagonda Ltd     V8 Vantage     4.7          8      6
# 4  2015  Aston Martin Lagonda Ltd   V8 Vantage S     4.7          8      7
#
#   FWD_RWD          DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  \
# 0       R  2-Wheel Drive, Rear        24       34            28       365
# 1       R  2-Wheel Drive, Rear        12       18            14       742
# 2       R  2-Wheel Drive, Rear        14       21            16       655
# 3       R  2-Wheel Drive, Rear        13       19            15       681
# 4       R  2-Wheel Drive, Rear        14       21            16       655
#
#    CO2_HWY  CO2_COMBINED
# 0      259           317
# 1      488           628
# 2      426           552
# 3      461           582
# 4      426           552

# %% [markdown]
# (1)	What car(s) have the highest MPG_COMBINED?

# %%
print df['MPG_COMBINED'].min()
# Out:
# 10

# %%
df['MPG_COMBINED'] == 10
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22       True
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1202    False
# 1203    False
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# 1215    False
# 1216    False
# 1217    False
# 1218    False
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# 1224    False
# 1225    False
# 1226    False
# 1227    False
# 1228    False
# 1229    False
# 1230    False
# 1231    False
# Name: MPG_COMBINED, dtype: bool

# %%
df [df['MPG_COMBINED'] == 10 ]
# Out:
#     YEAR MANUFACTURER   MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 22  2015      Bugatti  Veyron       8         16      7       A
#
#         DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 22  All Wheel Drive         8       15            10      1050      599
#
#     CO2_COMBINED
# 22           847

# %%
(2)	Which car(s) produce the least amount of CO2_COMBINED?

# %%
print df[ df['CO2_COMBINED'] ==  df['CO2_COMBINED'].min()   ]
# Out:
#      YEAR MANUFACTURER    MODEL  VOLUME  CYLINDERS  GEARS FWD_RWD  \
# 420  2015       TOYOTA  PRIUS c     1.5          4      1       F
# 640  2015       TOYOTA    PRIUS     1.8          4      1       F
#
#               DRIVE_DESCR  MPG_CITY  MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  \
# 420  2-Wheel Drive, Front        53       46            50       168      192
# 640  2-Wheel Drive, Front        51       48            50       174      183
#
#      CO2_COMBINED
# 420           178
# 640           178

# %%
(3) What is the correlation between VOLUME and the MPG_CITY?

# %%
df['VOLUME'].corr(df['MPG_CITY'])
# Out:
# -0.7643106705460665

# %%
(4) What is the correlation between MPG_CITY and MPG_HWY?

# %%
df['MGP_HWY'].corr(df['MPG_CITY'])
# Out:
# 0.91028902061931916

# %%
df['MPG_CITY'].corr(df['MGP_HWY'])
# Out:
# 0.91028902061931916

# %%
print df.groupby(['MGP_HWY'])
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x10e4d23d0>

# %%
df['MPG_CITY']
df.iloc[:,8]
# df.iloc['MPG_CITY']
# Out:
# 0       24
# 1       12
# 2       14
# 3       13
# 4       14
# 5       13
# 6       14
# 7       13
# 8       14
# 9       11
# 10      13
# 11      12
# 12      14
# 13      11
# 14      13
# 15      12
# 16      22
# 17      13
# 18      22
# 19      22
# 20      17
# 21      17
# 22       8
# 23      16
# 24      13
# 25      17
# 26      15
# 27      12
# 28      13
# 29      13
#         ..
# 1202    15
# 1203    15
# 1204    12
# 1205    12
# 1206    19
# 1207    17
# 1208    13
# 1209    13
# 1210    22
# 1211    17
# 1212    17
# 1213    18
# 1214    13
# 1215    12
# 1216    12
# 1217    25
# 1218    20
# 1219    17
# 1220    14
# 1221    17
# 1222    17
# 1223    18
# 1224    27
# 1225    28
# 1226    13
# 1227    13
# 1228    13
# 1229    20
# 1230    17
# 1231    20
# Name: MPG_CITY, dtype: int64

# %%
print df.ix[45]
df.ix[[45]]
df.shape
# Out:
# YEAR                               2015
# MANUFACTURER                     Jaguar
# MODEL           F-TYPE V8 S Convertible
# VOLUME                                5
# CYLINDERS                             8
# GEARS                                 8
# FWD_RWD                               R
# DRIVE_DESCR         2-Wheel Drive, Rear
# MPG_CITY                             16
# MGP_HWY                              23
# MPG_COMBINED                         18
# CO2_CITY                            570
# CO2_HWY                             386
# CO2_COMBINED                        487
# Name: 45, dtype: object
# (1232, 14)

# %%
df["MPG_CITY"]
# Out:
# 0       24
# 1       12
# 2       14
# 3       13
# 4       14
# 5       13
# 6       14
# 7       13
# 8       14
# 9       11
# 10      13
# 11      12
# 12      14
# 13      11
# 14      13
# 15      12
# 16      22
# 17      13
# 18      22
# 19      22
# 20      17
# 21      17
# 22       8
# 23      16
# 24      13
# 25      17
# 26      15
# 27      12
# 28      13
# 29      13
#         ..
# 1202    15
# 1203    15
# 1204    12
# 1205    12
# 1206    19
# 1207    17
# 1208    13
# 1209    13
# 1210    22
# 1211    17
# 1212    17
# 1213    18
# 1214    13
# 1215    12
# 1216    12
# 1217    25
# 1218    20
# 1219    17
# 1220    14
# 1221    17
# 1222    17
# 1223    18
# 1224    27
# 1225    28
# 1226    13
# 1227    13
# 1228    13
# 1229    20
# 1230    17
# 1231    20
# Name: MPG_CITY, dtype: int64

# %%
df.iloc[:,5]
# Out:
# 0       6
# 1       7
# 2       7
# 3       6
# 4       7
# 5       6
# 6       7
# 7       6
# 8       7
# 9       6
# 10      7
# 11      6
# 12      7
# 13      6
# 14      7
# 15      6
# 16      6
# 17      8
# 18      8
# 19      6
# 20      7
# 21      7
# 22      7
# 23      8
# 24      8
# 25      7
# 26      7
# 27      6
# 28      7
# 29      7
#        ..
# 1202    6
# 1203    6
# 1204    7
# 1205    7
# 1206    7
# 1207    7
# 1208    7
# 1209    7
# 1210    7
# 1211    7
# 1212    7
# 1213    7
# 1214    7
# 1215    5
# 1216    5
# 1217    1
# 1218    8
# 1219    8
# 1220    8
# 1221    5
# 1222    5
# 1223    6
# 1224    6
# 1225    6
# 1226    6
# 1227    6
# 1228    6
# 1229    8
# 1230    8
# 1231    8
# Name: GEARS, dtype: int64

# %%
df.iloc[3,3]
# Out:
# 4.7000000000000002

# %%
df.describe()
# Out:
#        YEAR       VOLUME    CYLINDERS        GEARS     MPG_CITY      MGP_HWY  \
# count  1232  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean   2015     3.264367     5.729708     6.397727    20.153409    27.928571
# std       0     1.384939     1.844700     1.408202     5.527423     6.182029
# min    2015     1.000000     3.000000     1.000000     8.000000    14.000000
# 25%    2015     2.000000     4.000000     6.000000    16.000000    23.000000
# 50%    2015     3.000000     6.000000     6.000000    19.000000    27.500000
# 75%    2015     3.800000     6.000000     7.000000    23.000000    32.000000
# max    2015     8.400000    16.000000     9.000000    53.000000    48.000000
#
#        MPG_COMBINED     CO2_CITY      CO2_HWY  CO2_COMBINED
# count   1232.000000  1232.000000  1232.000000   1232.000000
# mean      22.965909   473.239448   335.655844    411.293831
# std        5.685114   122.640050    76.549162    100.460943
# min       10.000000   168.000000   177.000000    178.000000
# 25%       19.000000   382.000000   278.000000    337.750000
# 50%       22.000000   461.000000   326.000000    401.000000
# 75%       26.250000   548.500000   382.000000    472.000000
# max       50.000000  1050.000000   624.000000    847.000000

# %%
df.sort(columns = 'MPG_COMBINED', ascending = False)
# Out:
# /Users/jam3jam/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#       YEAR                   MANUFACTURER                             MODEL  \
# 420   2015                         TOYOTA                           PRIUS c
# 640   2015                         TOYOTA                             PRIUS
# 543   2015                          Honda                            ACCORD
# 339   2015                          Honda                      CIVIC HYBRID
# 447   2015                     Volkswagen                      Jetta Hybrid
# 542   2015                           Ford                 FUSION HYBRID FWD
# 357   2015                          LEXUS                           CT 200h
# 787   2015                         TOYOTA                           PRIUS v
# 632   2015                         TOYOTA                   CAMRY HYBRID LE
# 633   2015                         TOYOTA               CAMRY HYBRID XLE/SE
# 406   2015  Mitsubishi Motors Corporation                            MIRAGE
# 598   2015                        Lincoln                    MKZ HYBRID FWD
# 629   2015                         TOYOTA                     AVALON HYBRID
# 584   2015                          LEXUS                           ES 300h
# 696   2015                           Ford                  C-MAX Hybrid FWD
# 559   2015          HYUNDAI MOTOR COMPANY                     Sonata HYBRID
# 582   2015         KIA MOTORS CORPORATION                     Optima HYBRID
# 407   2015  Mitsubishi Motors Corporation                            MIRAGE
# 560   2015          HYUNDAI MOTOR COMPANY             Sonata HYBRID LIMITED
# 268   2015                            BMW                              328d
# 583   2015         KIA MOTORS CORPORATION                  Optima HYBRID EX
# 38    2015                          Honda                              CR-Z
# 148   2015                          SCION                                iQ
# 201   2015                           Ford                    Fiesta SFE FWD
# 434   2015                     Volkswagen                              Golf
# 445   2015                     Volkswagen                             Jetta
# 153   2015                           Audi                                A3
# 66    2015                  Mercedes-Benz              Smart fortwo (COUPE)
# 442   2015                     Volkswagen                             Jetta
# 757   2015                          Honda                               FIT
# ...    ...                            ...                               ...
# 29    2015    Ferrari North America, Inc.                        458 Italia
# 13    2015                           Audi                         R8 Spyder
# 313   2015                      Chevrolet                            CAMARO
# 36    2015    Ferrari North America, Inc.                               F12
# 37    2015    Ferrari North America, Inc.                               F12
# 46    2015                    Lamborghini                   Aventador Coupe
# 49    2015                    Lamborghini                   Veneno Roadster
# 535   2015    Ferrari North America, Inc.                                FF
# 536   2015    Ferrari North America, Inc.                                FF
# 468   2015                        Bentley                          Mulsanne
# 872   2015                            GMC        G3500 SAVANA 2WD PASS MDPV
# 863   2015                      Chevrolet       G2500 EXPRESS 2WD PASS MDPV
# 871   2015                            GMC        G2500 SAVANA 2WD PASS MDPV
# 870   2015                            GMC        G2500 SAVANA 2WD PASS MDPV
# 1205  2015                  Mercedes-Benz                          G 63 AMG
# 1204  2015                  Mercedes-Benz                             G 550
# 869   2015                            GMC        G2500 SAVANA 2WD PASS MDPV
# 861   2015                      Chevrolet       G2500 EXPRESS 2WD PASS MDPV
# 862   2015                      Chevrolet       G2500 EXPRESS 2WD PASS MDPV
# 864   2015                      Chevrolet       G3500 EXPRESS 2WD PASS MDPV
# 859   2015                            GMC  G2500 SAVANA CONV 2WD CARGO MDPV
# 858   2015                      Chevrolet  G2500 EXPRESS CONV 2WD CARGOMDPV
# 857   2015                      Chevrolet  G2500 EXPRESS CONV 2WD CARGOMDPV
# 866   2015                      Chevrolet       G3500 EXPRESS 2WD PASS MDPV
# 865   2015                      Chevrolet       G3500 EXPRESS 2WD PASS MDPV
# 874   2015                            GMC        G3500 SAVANA 2WD PASS MDPV
# 47    2015                    Lamborghini                Aventador Roadster
# 873   2015                            GMC        G3500 SAVANA 2WD PASS MDPV
# 860   2015                            GMC  G2500 SAVANA CONV 2WD CARGO MDPV
# 22    2015                        Bugatti                            Veyron
#
#       VOLUME  CYLINDERS  GEARS FWD_RWD              DRIVE_DESCR  MPG_CITY  \
# 420      1.5          4      1       F     2-Wheel Drive, Front        53
# 640      1.8          4      1       F     2-Wheel Drive, Front        51
# 543      2.0          4      1       F     2-Wheel Drive, Front        50
# 339      1.5          4      1       F     2-Wheel Drive, Front        44
# 447      1.4          4      7       F     2-Wheel Drive, Front        42
# 542      2.0          4      1       F     2-Wheel Drive, Front        44
# 357      1.8          4      1       F     2-Wheel Drive, Front        43
# 787      1.8          4      1       F     2-Wheel Drive, Front        44
# 632      2.5          4      1       F     2-Wheel Drive, Front        43
# 633      2.5          4      1       F     2-Wheel Drive, Front        40
# 406      1.2          3      1       F     2-Wheel Drive, Front        37
# 598      2.0          4      1       F     2-Wheel Drive, Front        41
# 629      2.5          4      6       F     2-Wheel Drive, Front        40
# 584      2.5          4      6       F     2-Wheel Drive, Front        40
# 696      2.0          4      1       F     2-Wheel Drive, Front        42
# 559      2.4          4      6       F     2-Wheel Drive, Front        36
# 582      2.4          4      6       F     2-Wheel Drive, Front        36
# 407      1.2          3      5       F     2-Wheel Drive, Front        34
# 560      2.4          4      6       F     2-Wheel Drive, Front        36
# 268      2.0          4      8       R      2-Wheel Drive, Rear        32
# 583      2.4          4      6       F     2-Wheel Drive, Front        35
# 38       1.5          4      7       F     2-Wheel Drive, Front        36
# 148      1.3          4      1       F     2-Wheel Drive, Front        36
# 201      1.0          3      5       F     2-Wheel Drive, Front        31
# 434      2.0          4      6       F     2-Wheel Drive, Front        31
# 445      2.0          4      6       F     2-Wheel Drive, Front        31
# 153      2.0          4      6       F     2-Wheel Drive, Front        31
# 66       1.0          3      5       R      2-Wheel Drive, Rear        34
# 442      2.0          4      6       F     2-Wheel Drive, Front        31
# 757      1.5          4      1       F     2-Wheel Drive, Front        33
# ...      ...        ...    ...     ...                      ...       ...
# 29       4.5          8      7       R      2-Wheel Drive, Rear        13
# 13       4.2          8      6       A          All Wheel Drive        11
# 313      6.2          8      6       R      2-Wheel Drive, Rear        12
# 36       6.3         12      7       R      2-Wheel Drive, Rear        12
# 37       6.3         12      7       R      2-Wheel Drive, Rear        11
# 46       6.5         12      7       A          All Wheel Drive        11
# 49       6.5         12      7       A          All Wheel Drive        11
# 535      6.3         12      7       P  Part-time 4-Wheel Drive        11
# 536      6.3         12      7       P  Part-time 4-Wheel Drive        11
# 468      6.8          8      8       R      2-Wheel Drive, Rear        11
# 872      4.8          8      6       R      2-Wheel Drive, Rear        11
# 863      6.0          8      6       R      2-Wheel Drive, Rear        11
# 871      6.0          8      6       R      2-Wheel Drive, Rear        11
# 870      6.0          8      6       R      2-Wheel Drive, Rear        11
# 1205     5.5          8      7       4            4-Wheel Drive        12
# 1204     5.5          8      7       4            4-Wheel Drive        12
# 869      4.8          8      6       R      2-Wheel Drive, Rear        11
# 861      4.8          8      6       R      2-Wheel Drive, Rear        11
# 862      6.0          8      6       R      2-Wheel Drive, Rear        11
# 864      4.8          8      6       R      2-Wheel Drive, Rear        11
# 859      6.0          8      6       R      2-Wheel Drive, Rear        10
# 858      6.0          8      6       R      2-Wheel Drive, Rear        10
# 857      6.0          8      6       R      2-Wheel Drive, Rear        10
# 866      6.0          8      6       R      2-Wheel Drive, Rear        11
# 865      6.0          8      6       R      2-Wheel Drive, Rear        11
# 874      6.0          8      6       R      2-Wheel Drive, Rear        11
# 47       6.5         12      7       A          All Wheel Drive        10
# 873      6.0          8      6       R      2-Wheel Drive, Rear        11
# 860      6.0          8      6       R      2-Wheel Drive, Rear        10
# 22       8.0         16      7       A          All Wheel Drive         8
#
#       MGP_HWY  MPG_COMBINED  CO2_CITY  CO2_HWY  CO2_COMBINED
# 420        46            50       168      192           178
# 640        48            50       174      183           178
# 543        45            47       178      199           188
# 339        47            45       200      190           196
# 447        48            45       212      185           200
# 542        41            42       202      218           209
# 357        40            42       206      221           211
# 787        40            42       204      221           211
# 632        39            41       207      224           215
# 633        38            40       218      230           224
# 406        44            40       241      199           222
# 598        39            40       216      228           222
# 629        39            40       219      228           223
# 584        39            40       219      228           223
# 696        37            40       212      241           225
# 559        40            38       247      224           237
# 582        40            38       247      224           237
# 407        42            37       262      208           238
# 560        40            37       250      225           239
# 268        45            37       322      225           279
# 583        39            37       252      229           242
# 38         39            37       247      227           238
# 148        37            37       242      232           238
# 201        43            36       280      206           247
# 434        43            36       326      236           285
# 445        46            36       332      223           283
# 153        43            36       326      236           285
# 66         38            36       256      228           244
# 442        45            36       324      228           281
# 757        41            36       269      216           247
# ...       ...           ...       ...      ...           ...
# 29         17            14       701      525           622
# 13         20            14       772      439           622
# 313        18            14       760      499           643
# 36         16            13       760      557           669
# 37         16            13       776      561           679
# 46         18            13       836      481           676
# 49         17            13       831      523           692
# 535        17            13       803      539           684
# 536        16            13       825      541           697
# 468        18            13       840      501           688
# 872        17            13       792      535           676
# 863        16            13       830      564           710
# 871        16            13       830      564           710
# 870        16            13       830      564           710
# 1205       14            13       754      624           696
# 1204       15            13       756      601           686
# 869        17            13       791      534           675
# 861        17            13       791      534           675
# 862        16            13       830      564           710
# 864        17            13       794      536           678
# 859        15            12       868      582           740
# 858        15            12       875      590           747
# 857        15            12       868      582           740
# 866        16            12       844      572           721
# 865        16            12       840      568           718
# 874        16            12       842      571           720
# 47         16            12       902      547           742
# 873        16            12       837      567           716
# 860        15            12       875      590           747
# 22         15            10      1050      599           847
#
# [1232 rows x 14 columns]

# %%
df.groupby(['CYLINDERS'])['MPG_CITY'].mean()
# Out:
# CYLINDERS
# 3     31.181818
# 4     24.663327
# 5     19.500000
# 6     18.582367
# 8     14.545455
# 10    12.666667
# 12    12.148148
# 16     8.000000
# Name: MPG_CITY, dtype: float64

# %%
df.plot.area
# Out:
# <bound method FramePlotMethods.area of <pandas.tools.plotting.FramePlotMethods object at 0x10d655f50>>

# %%
# %matplotlib inline
df.groupby(['CYLINDERS'])['MPG_CITY'].mean().plot.bar()

# %%
df_ = df.iloc[:,1::]
df_.iloc[:,4].plot.hist(alpha=0.5)

# %%
import csv

# data= []
# with open('/Users/jam3jam/dsi/DSI-SM-1/DSI_SM_01/projects/01-projects-weekly/project-01/assets/sat_scores.csv', 'rU') as f:
#     reader = csv.reader(f)
#     for row in reader:
#         data.append(row)
# f.close()

data=[]
with open('/Users/jam3jam/Downloads/cars_2015_mpg.csv', 'rU') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
f.close()

# %%
data[4]
import numpy as np
np.mean(data[,4])
# Out:
#   File "<ipython-input-192-91d92d5c9193>", line 3
#     np.mean(data[,4])
#                  ^
# SyntaxError: invalid syntax
